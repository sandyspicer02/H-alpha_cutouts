# %%
#Natasha 
#Goal: Upload fits file and plot it using imshow
#Start with 113394 and 113078
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from astropy.io import fits
import glob
import os
from os.path import isfile, join
from os import listdir
import fitsio
from fitsio import FITS,FITSHDR
# %matplotlib inline

# %%
file1 = fits.open('A1367-113394-R.fits')
file2 = fits.open('A1367-113078-R.fits')

# %%
#file1.info()
#file2.info()
file1_data = fits.getdata('A1367-113394-R.fits')
file2_data = fits.getdata('A1367-113078-R.fits')

# %%
plt.imshow(file1_data, cmap='gray')
plt.colorbar()
plt.figure()
plt.imshow(file2_data, cmap= 'gray')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10b84fb00>

# %%
plt.imshow(file1_data)
plt.colorbar()
plt.figure()
plt.imshow(file2_data)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10bea0f80>

# %%
#trying to make code easier to use, grab all files at once and be
#able to plot them all at once

# %%
chosen_files = glob.glob('*.fits')

for filename in glob.glob('*.fits'):
    plt.figure()
    files = fits.open(filename)
    file_data = fits.getdata(filename)
    plt.imshow(file_data, cmap='gray')
    plt.colorbar()
