# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# %matplotlib inline

# %%
for cutouts in glob.glob('*.fits'):
    plt.figure()
    fits.open(cutouts)
    image_data = fits.getdata(cutouts)
    plt.imshow(image_data)
    plt.colorbar()
